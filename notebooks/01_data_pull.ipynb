# %% [markdown]
# # 01 — Data Pull
# Downloads all raw data from the College Football Data API.
# Prerequisite: set `CFBD_API_KEY` in `.env`.

# %%
import sys; sys.path.insert(0, '../src')
from data_loader import load_all
load_all()

# %%
import pandas as pd
from config import DATA_RAW

# Quick inspection of each file
for fname in ['games.csv','team_game_stats.csv','drives.csv','fourth_downs.csv','sec_season_stats.csv']:
    df = pd.read_csv(DATA_RAW / fname)
    print(f'{fname:30s}  {df.shape[0]:>5} rows  {df.shape[1]:>3} cols')
